0 (from graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/d2/92/c2b9464a0562feb6ae780bdc152364810862e07ef5e6affa2b7686028db2/matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
#      ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#      --------------------- ------------------ 4.2/7.8 MB 19.4 MB/s eta 0:00:01
#      ---------------------------------------- 7.8/7.8 MB 18.6 MB/s eta 0:00:00
# Collecting networkx<4,>=3 (from graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/38/e9/5f72929373e1a0e8d142a130f3f97e6ff920070f87f91c4e13e40e0fba5a/networkx-3.3-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 1.7/1.7 MB 18.5 MB/s eta 0:00:00
# Collecting nltk==3.9.1 (from graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/4d/66/7d9e26593edda06e8cb531874633f7c2372279c3b0f46235539fe546df8b/nltk-3.9.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------------------------------------- 1.5/1.5 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.25.2 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from graphrag) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=1.46.1 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from graphrag) (1.46.1)
# Collecting pandas<3.0.0,>=2.2.2 (from graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/29/d4/1244ab8edf173a10fd601f7e13b9566c1b525c4f365d6bee918e68381889/pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#      ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#      --------------- ------------------------ 4.5/11.5 MB 20.7 MB/s eta 0:00:01
#      ------------------------------ --------- 8.7/11.5 MB 20.7 MB/s eta 0:00:01
#      --------------------------------------- 11.5/11.5 MB 19.5 MB/s eta 0:00:00
# Collecting pyaml-env<2.0.0,>=1.2.1 (from graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/d7/9b/eb5d41a8ec8891ca85bac75b409d83f116b852fd46520f19c24464cba032/pyaml_env-1.2.1-py3-none-any.whl (9.0 kB)
# Collecting pyarrow<16.0.0,>=15.0.0 (from graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/cd/93/c2d3384aba712a0eb503f3940132189e81e97fb320844651783f45f15722/pyarrow-15.0.2-cp312-cp312-win_amd64.whl (25.3 MB)
#      ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
#      ----- ---------------------------------- 3.4/25.3 MB 16.8 MB/s eta 0:00:02
#      ------------ --------------------------- 7.6/25.3 MB 18.1 MB/s eta 0:00:01
#      ----------------- --------------------- 11.3/25.3 MB 18.1 MB/s eta 0:00:01
#      ---------------------- ---------------- 14.7/25.3 MB 18.1 MB/s eta 0:00:01
#      ----------------------------- --------- 18.9/25.3 MB 18.6 MB/s eta 0:00:01
#      ----------------------------------- --- 22.8/25.3 MB 19.0 MB/s eta 0:00:01
#      --------------------------------------- 25.3/25.3 MB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3.0.0,>=2.9.2 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from graphrag) (2.9.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from graphrag) (1.0.1)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from graphrag) (6.0.2)
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from graphrag) (13.8.1)
# Collecting tenacity<10.0.0,>=9.0.0 (from graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/b6/cb/b86984bed139586d01532a587464b5805f12e397594f19f931c4c2fbfa61/tenacity-9.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from graphrag) (0.7.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from graphrag) (4.12.2)
# Collecting umap-learn<0.6.0,>=0.5.6 (from graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/d1/1b/46802a050b1c55d10c4f59fc6afd2b45ac9b4f62b2e12092d3f599286f14/umap_learn-0.5.6-py3-none-any.whl (85 kB)
# Requirement already satisfied: click in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from nltk==3.9.1->graphrag) (8.1.7)
# Collecting joblib (from nltk==3.9.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl (301 kB)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from nltk==3.9.1->graphrag) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from nltk==3.9.1->graphrag) (4.66.5)
# Collecting azure-core>=1.31.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/01/8e/fcb6a77d3029d2a7356f38dbc77cf7daa113b81ddab76b5593d23321e44c/azure_core-1.31.0-py3-none-any.whl (197 kB)
# Collecting cryptography>=2.5 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/b3/c6/c09cee6968add5ff868525c3815e5dccc0e3c6e89eec58dc9135d3c40e88/cryptography-43.0.1-cp39-abi3-win_amd64.whl (3.1 MB)
#      ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#      ---------------------------------------- 3.1/3.1 MB 20.1 MB/s eta 0:00:00
# Collecting msal>=1.30.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages
8 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib<4.0.0,>=3.9.0->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e5/0c/0e3c05b1c87bb6a1c76d281b0f35e78d2d80ac91b5f8f524cebf77f51049/pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hiron\appdata\roaming\python\python312\site-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (2.8.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.46.1->graphrag) (4.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.46.1->graphrag) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.46.1->graphrag) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.46.1->graphrag) (0.5.0)
# Requirement already satisfied: sniffio in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.46.1->graphrag) (1.3.1)
# Collecting pytz>=2020.1 (from pandas<3.0.0,>=2.2.2->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/11/c3/005fcca25ce078d2cc29fd559379817424e94885510568bc1bc53d7d5846/pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=2.2.2->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/65/58/f9c9e6be752e9fcb8b6a0ee9fb87e6e7a1f6bcab2cdc73f02bb7ba91ada0/tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.9.2->graphrag) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.9.2->graphrag) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from rich<14.0.0,>=13.6.0->graphrag) (3.0.0)
# Collecting numba>=0.51.2 (from umap-learn<0.6.0,>=0.5.6->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ca/bd/0fe29fcd1b6a8de479a4ed25c6e56470e467e3611c079d55869ceef2b6d1/numba-0.60.0-cp312-cp312-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#      ---------------------------------------- 2.7/2.7 MB 19.6 MB/s eta 0:00:00
# Collecting pynndescent>=0.5 (from umap-learn<0.6.0,>=0.5.6->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/d2/53/d23a97e0a2c690d40b165d1062e2c4ccc796be458a1ce59f6ba030434663/pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.46.1->graphrag) (3.10)
# Requirement already satisfied: six in c:\users\hiron\appdata\roaming\python\python312\site-packages (from anytree<3.0.0,>=2.12.1->graspologic<4.0.0,>=3.4.1->graphrag) (1.16.0)
# Collecting cffi>=1.12 (from cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/50/b9/db34c4755a7bd1cb2d1603ac3863f22bcecbd1ba29e5ee841a4bc510b294/cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Collecting smart-open>=1.8.1 (from gensim<5.0.0,>=4.3.2->graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/65/12/cc24847b4b0b124501a33cd8f7963f79f6f6584bc7f2f4fc16bbbaa54c8f/smart_open-7.0.4-py3-none-any.whl (61 kB)
# Requirement already satisfied: certifi in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.46.1->graphrag) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.46.1->graphrag) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.46.1->graphrag) (0.14.0)
# Collecting autograd>=1.3 (from hyppo<0.5.0,>=0.4.0->graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/6d/90/d13cf396989052cadd8511c1878b0913bbce28eeef5feb95710a92e03076/autograd-1.7.0-py3-none-any.whl (52 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ee/07/44bd408781594c4d0a027666ef27fab1e441b109dc3b76b4f836f8fd04fe/jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/b7/59/2056f61236782a2c86b33906c025d4f4a0b17be0161b63b70fd9e8775d36/referencing-0.35.1-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ec/2f/b938864d66b86a6e4acadefdc56de75ef56f7cafdfd568a6464605457bd5/rpds_py-0.20.0-cp312-none-win_amd64.whl (214 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->graphrag) (0.1.2)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/79/84/0fdf9b18ba31d69877bd39c9cd6052b47f3761e9910c15de788e519f079f/PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Collecting portalocker<3,>=1.4 (from msal-extensions>=1.2.0->azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/9b/fb/a70a4214956182e0d7a9099ab17d50bfcba1056188e9b14f35b9e2b62a0d/portalocker-2.10.1-py3-none-any.whl (18 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.51.2->umap-learn<0.6.0,>=0.5.6->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/c6/94/dea10e263655ce78d777e78d904903faae39d1fc440762be4a9dc46bed49/llvmlite-0.43.0-cp312-cp312-win_amd64.whl (28.1 MB)
#      ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#      ----- ---------------------------------- 3.7/28.1 MB 18.2 MB/s eta 0:00:02
#      ----------- ---------------------------- 8.4/28.1 MB 20.8 MB/s eta 0:00:01
#      ----------------- --------------------- 12.3/28.1 MB 19.3 MB/s eta 0:00:01
#      ---------------------- ---------------- 16.0/28.1 MB 19.4 MB/s eta 0:00:01
#      ---------------------------- ---------- 20.2/28.1 MB 19.6 MB/s eta 0:00:01
#      --------------------------------- ----- 24.1/28.1 MB 19.6 MB/s eta 0:00:01
#      --------------------------------------  28.0/28.1 MB 19.5 MB/s eta 0:00:01
#      --------------------------------------- 28.1/28.1 MB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31.0->lancedb<0.14.0,>=0.13.0->graphrag) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31.0->lancedb<0.14.0,>=0.13.0->graphrag) (2.2.3)
# Requirement already satisfied: decorator>=3.4.2 in c:\users\hiron\appdata\roaming\python\python312\site-packages (from retry>=0.9.2->lancedb<0.14.0,>=0.13.0->graphrag) (5.1.1)
# Collecting py<2.0.0,>=1.4.26 (from retry>=0.9.2->lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/f6/f0/10642828a8dfb741e5f3fbaac830550a518a775c7fff6f04a007259b0548/py-1.11.0-py2.py3-none-any.whl (98 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2.0.0,>=1.4.2->graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting patsy>=0.5.6 (from statsmodels<0.15.0,>=0.14.2->graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/43/f3/1d311a09c34f14f5973bb0bb0dc3a6e007e1eda90b5492d082689936ca51/patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: colorama in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from tqdm->nltk==3.9.1->graphrag) (0.4.6)
# Collecting pycparser (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading https://mirrors.aliyun.com/pypi/packages/13/a3/a812df4e2dd5696d1f351d58b8fe16a405b234ad2886a0dab9183fb78109/pycparser-2.22-py3-none-any.whl (117 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\hiron\appdata\roaming\python\python312\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity<2.0.0,>=1.17.1->graphrag) (306)
# Requirement already satisfied: wrapt in c:\users\hiron\appdata\local\programs\python\python312\lib\site-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.3.2->graspologic<4.0.0,>=3.4.1->graphrag) (1.16.0)
# Installing collected packages: pytz, azure-common, tzdata, threadpoolctl, tenacity, smart-open, scipy, rpds-py, pyparsing, PyJWT, pycparser, pyarrow, pyaml-env, py, portalocker, pillow, patsy, networkx, llvmlite, kiwisolver, json-repair, joblib, isodate, graspologic-native, future, fonttools, diskcache, deprecation, cycler, contourpy, beartype, autograd, anytree, aiolimiter, aiofiles, scikit-learn, retry, referencing, pylance, POT, pandas, numba, nltk, matplotlib, gensim, environs, devtools, cffi, azure-core, statsmodels, seaborn, pynndescent, lancedb, jsonschema-specifications, hyppo, cryptography, azure-search-documents, umap-learn, jsonschema, azure-storage-blob, msal, graspologic, datashaper, msal-extensions, azure-identity, graphrag
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.5.0
#     Uninstalling tenacity-8.5.0:
#       Successfully uninstalled tenacity-8.5.0
# Successfully installed POT-0.9.4 PyJWT-2.9.0 aiofiles-24.1.0 aiolimiter-1.1.0 anytree-2.12.1 autograd-1.7.0 azure-common-1.1.28 azure-core-1.31.0 azure-identity-1.18.0 azure-search-documents-11.5.1 azure-storage-blob-12.23.0 beartype-0.18.5 cffi-1.17.1 contourpy-1.3.0 cryptography-43.0.1 cycler-0.12.1 datashaper-0.0.49 deprecation-2.1.0 devtools-0.12.2 diskcache-5.6.3 environs-11.0.0 fonttools-4.53.1 future-1.0.0 gensim-4.3.3 graphrag-0.3.6 graspologic-3.4.1 graspologic-native-1.2.1 hyppo-0.4.0 isodate-0.6.1 joblib-1.4.2 json-repair-0.28.4 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 kiwisolver-1.4.7 lancedb-0.13.0 llvmlite-0.43.0 matplotlib-3.9.2 msal-1.31.0 msal-extensions-1.2.0 networkx-3.3 nltk-3.9.1 numba-0.60.0 pandas-2.2.3 patsy-0.5.6 pillow-10.4.0 portalocker-2.10.1 py-1.11.0 pyaml-env-1.2.1 pyarrow-15.0.2 pycparser-2.22 pylance-0.17.0 pynndescent-0.5.13 pyparsing-3.1.4 pytz-2024.2 referencing-0.35.1 retry-0.9.2 rpds-py-0.20.0 scikit-learn-1.5.2 scipy-1.12.0 seaborn-0.13.2 smart-open-7.0.4 statsmodels-0.14.3 tenacity-9.0.0 threadpoolctl-3.5.0 tzdata-2024.1 umap-learn-0.5.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.0 requires tenacity!=8.4.0,<9.0.0,>=8.1.0, but you have tenacity 9.0.0 which is incompatible.
# langchain-community 0.3.0 requires tenacity!=8.4.0,<9.0.0,>=8.1.0, but you have tenacity 9.0.0 which is incompatible.
# langchain-core 0.3.2 requires tenacity!=8.4.0,<9.0.0,>=8.1.0, but you have tenacity 9.0.0 which is incompatible.

# %%
# setup workspace
! python -m graphrag.index --init --root ./data
# Out:
# ⠋ GraphRAG Indexer
# Initializing project at ./data
# ⠋ GraphRAG Indexer

# %%
# .env
# GRAPHRAG_API_KEY=
# GRAPHRAG_API_BASE=

# modify llm.model & llm.api_base & embedding.llm.api_base in settings.yaml

# place data.txt under ./data/input
! mkdir ./data/input
# Out:
# �����﷨����ȷ��

# %%
# build Graphrag index
! python -m graphrag.index --root ./data
# Out:
# ⠋ GraphRAG Indexer
# Logging enabled at
# D:\CloudNative\AIOps\Camp\module_03\demo_08\data\output\indexing-engine.log
# ⠋ GraphRAG Indexer
# ⠋ GraphRAG Indexer
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\
# core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and
# will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
#     └── Verb filter --------------------------------------   0% -:--:-- 0:00:00
# 🚀 create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
#                                  id  ... n_tokens
# 0  fd2ab57504dcf41d143dbb42aa4075c1  ...      515
#
# [1 rows x 5 columns]
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# 🚀 create_base_extracted_entities
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# 🚀 create_summarized_entities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
# 🚀 create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
#    level                                    clustered_graph
# 0      0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\
# core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and
# will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
#     └── Verb filter --------------------------------------   0% -:--:-- 0:00:00
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
#     └── Verb text_embed ----------------------------------   0% -:--:-- 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
#     └── Verb text_embed ----------------------------------   0% -:--:-- 0:00:01
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
#     └── Verb text_embed ----------------------------------   0% -:--:-- 0:00:02
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\
# core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and
# will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
#     └── Verb filter --------------------------------------   0% -:--:-- 0:00:00
# 🚀 create_final_entities
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
#                                   id  ...
# description_embedding
# 0   0ad674d2abc24ede8404543feb798e85  ...  [-0.02304152213037014,
# -0.03685358539223671, 0...
# 1   04e73f980fcf41348d8448c79fddf03a  ...  [-0.0022111525759100914,
# 0.025228489190340042,...
# 2   87cb97dd6b70428190f0a74538649adb  ...  [0.0035705838818103075,
# 0.01770751178264618, 0...
# 3   ddeaf08ea52e41ba8c2dc39143c45e4e  ...  [-0.02960101328790188,
# 0.01305998582392931, 0....
# 4   2cecd72abe7c4b74baf7e14280daeec2  ...  [-0.033949751406908035,
# 0.0043969787657260895,...
# 5   a7d32c5bbbc14d739602f992794bccdb  ...  [-0.03702162578701973,
# -0.005153705831617117, ...
# 6   41c1039af4f746e58c68d99fb04a90d7  ...  [-0.001338861184194684,
# -0.01047198474407196, ...
# 7   518a4f27ac354993aaefe5d10682c363  ...  [-0.016275474801659584,
# 0.02842000499367714, 0...
# 8   34441cfbad2c407fbc9d4881e6c16084  ...  [-0.009428759105503559,
# -0.020215166732668877,...
# 9   0bb2a41b9b144037bc61d0698224db7e  ...  [0.009380033239722252,
# -0.01019288320094347, 0...
# 10  f901a9b3bfb142158d3159dc33a0ca34  ...  [-0.02484828419983387,
# 0.03824325278401375, 0....
# 11  141c75d936e9403990030d90635c3e1d  ...  [-0.017834298312664032,
# 0.010733311995863914, ...
# 12  ad3e4b59ce8049288f52d6bad8a13a00  ...  [0.01717427559196949,
# -0.008428660221397877, 0...
# 13  cb2579566fa64e109533d7fe52624bc7  ...  [-0.012644033879041672,
# -0.011380827985703945,...
#
# [14 rows x 8 columns]
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\
# core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and
# will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
#     └── Verb filter --------------------------------------   0% -:--:-- 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\datash
# aper\engine\verbs\convert.py:72: FutureWarning: errors='ignore' is deprecated
# and will raise in a future version. Use to_datetime without passing `errors`
# and catch exceptions explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
#     └── Verb convert -------------------------------------   0% -:--:-- 0:00:00
# c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\datash
# aper\engine\verbs\convert.py:72: UserWarning: Could not infer format, so each
# element will be parsed individually, falling back to `dateutil`. To ensure
# parsing is consistent and as-expected, please specify a format.
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
#     └── Verb convert -------------------------------------   0% -:--:-- 0:00:00
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# 🚀 create_final_nodes
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
#     level                        title  ...  x  y
# 0       0               PAYMENT SYSTEM  ...  0  0
# 1       0              OPERATIONS TEAM  ...  0  0
# 2       0                   PROMETHEUS  ...  0  0
# 3       0                      GRAFANA  ...  0  0
# 4       0              SYSTEM DOWNTIME  ...  0  0
# 5       0              PAYMENT FAILURE  ...  0  0
# 6       0              DATA ENCRYPTION  ...  0  0
# 7       0          BACKUP AND RECOVERY  ...  0  0
# 8       0                 LOAD TESTING  ...  0  0
# 9       0  COMMON ISSUES AND SOLUTIONS  ...  0  0
# 10      0        MONITORING AND ALERTS  ...  0  0
# 11      0      SECURITY BEST PRACTICES  ...  0  0
# 12      0     PERFORMANCE OPTIMIZATION  ...  0  0
# 13      0          SYSTEM ARCHITECTURE  ...  0  0
#
# [14 rows x 14 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# └── create_final_communities
# 🚀 create_final_communities
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# └── create_final_communities
#   id  ...                       text_unit_ids
# 0  0  ...
#
# [1 rows x 5 columns]
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# └── create_final_communities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# └── create_final_relationships
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# └── create_final_relationships
# 🚀 create_final_relationships
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# └── create_final_relationships
#             source                       target  ...  target_degree rank
# 0   PAYMENT SYSTEM              OPERATIONS TEAM  ...              1   14
# 1   PAYMENT SYSTEM                   PROMETHEUS  ...              1   14
# 2   PAYMENT SYSTEM                      GRAFANA  ...              1   14
# 3   PAYMENT SYSTEM              SYSTEM DOWNTIME  ...              1   14
# 4   PAYMENT SYSTEM              PAYMENT FAILURE  ...              1   14
# 5   PAYMENT SYSTEM              DATA ENCRYPTION  ...              1   14
# 6   PAYMENT SYSTEM          BACKUP AND RECOVERY  ...              1   14
# 7   PAYMENT SYSTEM                 LOAD TESTING  ...              1   14
# 8   PAYMENT SYSTEM          SYSTEM ARCHITECTURE  ...              1   14
# 9   PAYMENT SYSTEM  COMMON ISSUES AND SOLUTIONS  ...              1   14
# 10  PAYMENT SYSTEM        MONITORING AND ALERTS  ...              1   14
# 11  PAYMENT SYSTEM      SECURITY BEST PRACTICES  ...              1   14
# 12  PAYMENT SYSTEM     PERFORMANCE OPTIMIZATION  ...              1   14
#
# [13 rows x 10 columns]
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# └── create_final_relationships
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# └── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# └── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# └── create_final_text_units
# 🚀 create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# └── create_final_text_units
#                                  id  ...
# relationship_ids
# 0  fd2ab57504dcf41d143dbb42aa4075c1  ...  [e4f5ee6ff9954fa4b48089d51fe3cb81,
# 53885976d62...
#
# [1 rows x 6 columns]
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# └── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#     └── Verb create_community_reports --------------------   0% -:--:-- 0:00:00
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#     └── Verb create_community_reports --------------------   0% -:--:-- 0:00:01
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#     └── Verb create_community_reports --------------------   0% -:--:-- 0:00:02
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#     └── Verb create_community_reports --------------------   0% -:--:-- 0:00:03
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#     └── Verb create_community_reports --------------------   0% -:--:-- 0:00:04
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#     └── Verb create_community_reports --------------------   0% -:--:-- 0:00:05
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#     └── Verb create_community_reports --------------------   0% -:--:-- 0:00:06
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#     └── Verb create_community_reports --------------------   0% -:--:-- 0:00:07
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# 🚀 create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#   community  ...                                    id
# 0         0  ...  dcec82a4-bc2b-4d62-af19-d8af713e0777
#
# [1 rows x 10 columns]
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\datash
# aper\engine\verbs\convert.py:72: FutureWarning: errors='ignore' is deprecated
# and will raise in a future version. Use to_datetime without passing `errors`
# and catch exceptions explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
#     └── Verb convert -------------------------------------   0% -:--:-- 0:00:00
# 🚀 create_base_documents
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
#                                  id  ...     title
# 0  71a755d72c98bc1a77619cd24a938451  ...  data.txt
#
# [1 rows x 4 columns]
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
# └── create_final_documents
# 🚀 create_final_documents
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
# └── create_final_documents
#                                  id  ...     title
# 0  71a755d72c98bc1a77619cd24a938451  ...  data.txt
#
# [1 rows x 4 columns]
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
# └── create_final_documents
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
# └── create_final_documents
# 🚀 All workflows completed successfully.

# %%
# query
! python -m graphrag.query --root ./data --method global "backup"
# Out:
# creating llm client with {'api_key': 'REDACTED,len=51', 'type': "openai_chat", 'model': 'gpt-4o-mini', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': 'https://api.apiyi.com/v1', 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
#
# SUCCESS: Global Search Response:
# ## Importance of Backup and Recovery Procedures
#
# Backup and recovery procedures are critical components in maintaining the integrity and availability of payment systems. These processes are designed to ensure that, in the event of a system failure, the payment system can be restored swiftly. This capability is essential for minimizing downtime and preventing the loss of transactions, which can have significant implications for both businesses and customers.
#
# ### Safeguarding Against Data Loss
#
# The relationship between backup and recovery processes and the payment system underscores the necessity of having robust procedures in place. Such measures are vital for safeguarding against data loss and operational disruptions. Without effective backup strategies, organizations may face prolonged outages, which could lead to financial losses and damage to their reputation.
#
# ### Conclusion
#
# In summary, implementing comprehensive backup and recovery procedures shall be a priority for any organization that relies on payment systems. These procedures not only protect against data loss but also ensure that operations can continue smoothly, thereby maintaining customer trust and satisfaction [Data: Reports (0)].

# %%
# start Neo4j
# cred: neo4j/neo4j
! docker run -d \
    -p 7474:7474 -p 7687:7687 \
    --name neo4j-apoc \
    -e NEO4J_apoc_export_file_enabled=true \
    -e NEO4J_apoc_import_file_enabled=true \
    -e NEO4J_apoc_import_file_use__neo4j__config=true \
    -e NEO4J_PLUGINS=\[\"apoc\"\] \
    neo4j:5.21.2
# Out:
# f79e87dd710d259134ebb1bfc532351eb8c048ee104f7710045704374e395022
# Unable to find image 'neo4j:5.21.2' locally
# 5.21.2: Pulling from library/neo4j
# 5de87e84afee: Pulling fs layer
# 5f5c50d2d095: Pulling fs layer
# 399c5e0f462c: Pulling fs layer
# 1d820b141c5e: Pulling fs layer
# f688f7383f49: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# 1d820b141c5e: Waiting
# f688f7383f49: Waiting
# 4f4fb700ef54: Waiting
# 399c5e0f462c: Verifying Checksum
# 399c5e0f462c: Download complete
# 5de87e84afee: Verifying Checksum
# 5de87e84afee: Download complete
# 5de87e84afee: Pull complete
# 1d820b141c5e: Download complete
# 4f4fb700ef54: Download complete
# 5f5c50d2d095: Verifying Checksum
# 5f5c50d2d095: Download complete
# 5f5c50d2d095: Pull complete
# 399c5e0f462c: Pull complete
# 1d820b141c5e: Pull complete
# f688f7383f49: Verifying Checksum
# f688f7383f49: Download complete
# f688f7383f49: Pull complete
# 4f4fb700ef54: Pull complete
# Digest: sha256:fb93fab86f5e0f3e9782ba5bdfbe93578994e244ab114a5c9edc0ce292a0db5f
# Status: Downloaded newer image for neo4j:5.21.2

# %%
! pip install --quiet pandas neo4j-rust-ext

# %%
import pandas as pd
from neo4j import GraphDatabase
import time

# change dir
GRAPHRAG_FOLDER = "./data/output"

NEO4J_URI = "neo4j://localhost"  # or neo4j+s://xxxx.databases.neo4j.io
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "jhw5252jimmY!"
NEO4J_DATABASE = "neo4j"

# Create a Neo4j driver
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

statements = """
create constraint chunk_id if not exists for (c:__Chunk__) require c.id is unique;
create constraint document_id if not exists for (d:__Document__) require d.id is unique;
create constraint entity_id if not exists for (c:__Community__) require c.community is unique;
create constraint entity_id if not exists for (e:__Entity__) require e.id is unique;
create constraint entity_title if not exists for (e:__Entity__) require e.name is unique;
create constraint entity_title if not exists for (e:__Covariate__) require e.title is unique;
create constraint related_id if not exists for ()-[rel:RELATED]->() require rel.id is unique;
""".split(";")

for statement in statements:
    if len((statement or "").strip()) > 0:
        print(statement)
        driver.execute_query(statement)


def batched_import(statement, df, batch_size=1000):
    """
    Import a dataframe into Neo4j using a batched approach.
    Parameters: statement is the Cypher query to execute, df is the dataframe to import, and batch_size is the number of rows to import in each batch.
    """
    total = len(df)
    start_s = time.time()
    for start in range(0,total, batch_size):
        batch = df.iloc[start: min(start+batch_size,total)]
        result = driver.execute_query("UNWIND $rows AS value " + statement, 
                                      rows=batch.to_dict('records'),
                                      database_=NEO4J_DATABASE)
        print(result.summary.counters)
    print(f'{total} rows in { time.time() - start_s} s.')    
    return total

doc_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_documents.parquet', columns=["id", "title"])
doc_df.head(2)

# import documents
statement = """
MERGE (d:__Document__ {id:value.id})
SET d += value {.title}
"""

batched_import(statement, doc_df)

text_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_text_units.parquet',
                          columns=["id","text","n_tokens","document_ids"])
text_df.head(2)

statement = """
MERGE (c:__Chunk__ {id:value.id})
SET c += value {.text, .n_tokens}
WITH c, value
UNWIND value.document_ids AS document
MATCH (d:__Document__ {id:document})
MERGE (c)-[:PART_OF]->(d)
"""

batched_import(statement, text_df)

entity_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_entities.parquet',
                            columns=["name", "type", "description", "human_readable_id", "id", "description_embedding",
                                     "text_unit_ids"])
entity_df.head(2)

entity_statement = """
MERGE (e:__Entity__ {id:value.id})
SET e += value {.human_readable_id, .description, name:replace(value.name,'"','')}
WITH e, value
CALL db.create.setNodeVectorProperty(e, "description_embedding", value.description_embedding)
CALL apoc.create.addLabels(e, case when coalesce(value.type,"") = "" then [] else [apoc.text.upperCamelCase(replace(value.type,'"',''))] end) yield node
UNWIND value.text_unit_ids AS text_unit
MATCH (c:__Chunk__ {id:text_unit})
MERGE (c)-[:HAS_ENTITY]->(e)
"""

batched_import(entity_statement, entity_df)

rel_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_relationships.parquet',
                         columns=["source", "target", "id", "rank", "weight", "human_readable_id", "description",
                                  "text_unit_ids"])
rel_df.head(2)

rel_statement = """
    MATCH (source:__Entity__ {name:replace(value.source,'"','')})
    MATCH (target:__Entity__ {name:replace(value.target,'"','')})
    // not necessary to merge on id as there is only one relationship per pair
    MERGE (source)-[rel:RELATED {id: value.id}]->(target)
    SET rel += value {.rank, .weight, .human_readable_id, .description, .text_unit_ids}
    RETURN count(*) as createdRels
"""

batched_import(rel_statement, rel_df)

community_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_communities.parquet',
                               columns=["id", "level", "title", "text_unit_ids", "relationship_ids"])

community_df.head(2)

statement = """
MERGE (c:__Community__ {community:value.id})
SET c += value {.level, .title}
/*
UNWIND value.text_unit_ids as text_unit_id
MATCH (t:__Chunk__ {id:text_unit_id})
MERGE (c)-[:HAS_CHUNK]->(t)
WITH distinct c, value
*/
WITH *
UNWIND value.relationship_ids as rel_id
MATCH (start:__Entity__)-[:RELATED {id:rel_id}]->(end:__Entity__)
MERGE (start)-[:IN_COMMUNITY]->(c)
MERGE (end)-[:IN_COMMUNITY]->(c)
RETURn count(distinct c) as createdCommunities
"""

batched_import(statement, community_df)

community_report_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_community_reports.parquet',
                                      columns=["id", "community", "level", "title", "summary", "findings", "rank",
                                               "rank_explanation", "full_content"])
community_report_df.head(2)
# import communities
community_statement = """MATCH (c:__Community__ {community: value.community})
SET c += value {.level, .title, .rank, .rank_explanation, .full_content, .summary}
WITH c, value
UNWIND range(0, size(value.findings)-1) AS finding_idx
WITH c, value, finding_idx, value.findings[finding_idx] as finding
MERGE (c)-[:HAS_FINDING]->(f:Finding {id: finding_idx})
SET f += finding"""
batched_import(community_statement, community_report_df)
# Out:
# create constraint chunk_id if not exists for (c:__Chunk__) require c.id is unique
#
# create constraint document_id if not exists for (d:__Document__) require d.id is unique
#
# create constraint entity_id if not exists for (c:__Community__) require c.community is unique
#
# create constraint entity_id if not exists for (e:__Entity__) require e.id is unique
#
# create constraint entity_title if not exists for (e:__Entity__) require e.name is unique
#
# create constraint entity_title if not exists for (e:__Covariate__) require e.title is unique
#
# create constraint related_id if not exists for ()-[rel:RELATED]->() require rel.id is unique
# {'_contains_updates': True, 'labels_added': 1, 'nodes_created': 1, 'properties_set': 2}
# 1 rows in 0.06883049011230469 s.
# {'_contains_updates': True, 'labels_added': 1, 'relationships_created': 1, 'nodes_created': 1, 'properties_set': 3}
# 1 rows in 0.07933926582336426 s.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[10], line 90
#      77 entity_df.head(2)
#      79 entity_statement = """
#      80 MERGE (e:__Entity__ {id:value.id})
#      81 SET e += value {.human_readable_id, .description, name:replace(value.name,'"','')}
#    (...)
#      87 MERGE (c)-[:HAS_ENTITY]->(e)
#      88 """
# ---> 90 batched_import(entity_statement, entity_df)
#      92 rel_df = pd.read_parquet(f'{GRAPHRAG_FOLDER}/create_final_relationships.parquet',
#      93                          columns=["source", "target", "id", "rank", "weight", "human_readable_id", "description",
#      94                                   "text_unit_ids"])
#      95 rel_df.head(2)
#
# Cell In[10], line 41, in batched_import(statement, df, batch_size)
#      39 for start in range(0,total, batch_size):
#      40     batch = df.iloc[start: min(start+batch_size,total)]
# ---> 41     result = driver.execute_query("UNWIND $rows AS value " + statement,
#      42                                   rows=batch.to_dict('records'),
#      43                                   database_=NEO4J_DATABASE)
#      44     print(result.summary.counters)
#      45 print(f'{total} rows in { time.time() - start_s} s.')
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\driver.py:959, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     956     raise ValueError("Invalid routing control value: %r"
#     957                      % routing_)
#     958 with session._pipelined_begin:
# --> 959     return session._run_transaction(
#     960         access_mode, TelemetryAPI.DRIVER,
#     961         work, (query_str, parameters, result_transformer_), {}
#     962     )
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\work\session.py:554, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     552 tx = self._transaction
#     553 try:
# --> 554     result = transaction_function(tx, *args, **kwargs)
#     555 except asyncio.CancelledError:
#     556     # if cancellation callback has not been called yet:
#     557     if self._transaction is not None:
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\driver.py:1290, in _work(tx, query, parameters, transformer)
#    1284 def _work(
#    1285     tx: ManagedTransaction,
#    1286     query: te.LiteralString,
#    1287     parameters: t.Dict[str, t.Any],
#    1288     transformer: t.Callable[[Result], t.Union[_T]]
#    1289 ) -> _T:
# -> 1290     res = tx.run(query, parameters)
#    1291     return transformer(res)
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\work\transaction.py:172, in TransactionBase.run(self, query, parameters, **kwparameters)
#     169 self._results.append(result)
#     171 parameters = dict(parameters or {}, **kwparameters)
# --> 172 result._tx_ready_run(query, parameters)
#     174 return result
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\work\result.py:171, in Result._tx_ready_run(self, query, parameters)
#     167 def _tx_ready_run(self, query, parameters):
#     168     # BEGIN+RUN does not carry any extra on the RUN message.
#     169     # BEGIN {extra}
#     170     # RUN "query" {parameters} {extra}
# --> 171     self._run(query, parameters, None, None, None, None, None, None)
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\work\result.py:221, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     219 self._pull()
#     220 self._connection.send_all()
# --> 221 self._attach()
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\work\result.py:409, in Result._attach(self)
#     407 if self._exhausted is False:
#     408     while self._attached is False:
# --> 409         self._connection.fetch_message()
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     176 def inner(*args, **kwargs):
#     177     try:
# --> 178         func(*args, **kwargs)
#     179     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\io\_bolt.py:860, in Bolt.fetch_message(self)
#     856 # Receive exactly one message
#     857 tag, fields = self.inbox.pop(
#     858     hydration_hooks=self.responses[0].hydration_hooks
#     859 )
# --> 860 res = self._process_message(tag, fields)
#     861 self.idle_since = monotonic()
#     862 return res
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\io\_bolt5.py:370, in Bolt5x0._process_message(self, tag, fields)
#     368 self._server_state_manager.state = self.bolt_states.FAILED
#     369 try:
# --> 370     response.on_failure(summary_metadata or {})
#     371 except (ServiceUnavailable, DatabaseUnavailable):
#     372     if self.pool:
#
# File c:\Users\hiron\AppData\Local\Programs\Python\Python312\Lib\site-packages\neo4j\_sync\io\_common.py:245, in Response.on_failure(self, metadata)
#     243 handler = self.handlers.get("on_summary")
#     244 Util.callback(handler)
# --> 245 raise Neo4jError.hydrate(**metadata)
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureNotFound} {message: There is no procedure with the name `apoc.create.addLabels` registered for this database instance. Please ensure you've spelled the procedure name correctly and that the procedure is properly deployed.}
